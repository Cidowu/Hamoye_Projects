# %% [markdown]
# <a href="https://colab.research.google.com/github/Cidowu/Hamoye_Projects/blob/main/Energy_Efficiency_Tag_Along.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import all important modules
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
#Load the data
enr_df = pd.read_csv("/content/my_data/energydata_complete.csv")
enr_df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
#Explore the loaded dataset
enr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
enr_df.shape
# Out:
# (19735, 29)

# %%
enr_df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
#normalize the data

scaler = StandardScaler()
enr_df = enr_df.drop(columns = ["date"])
norm_df = pd.DataFrame(scaler.fit_transform(enr_df), columns = enr_df.columns)

# %%
enr_df
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
#Question 17
x_train, x_test, y_train, y_test = train_test_split(
    enr_df[["T2"]], enr_df["T6"], test_size = 0.3, random_state = 1
)

linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
predicted_values = linear_model.predict(x_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 3.612

# %%
#Question 18
enr_df2 = pd.read_csv("/content/my_data/energydata_complete.csv")
enr_df2 = enr_df2.drop(columns = ["date", "lights"])

# %%
scaler2 = MinMaxScaler()
enr_norm = pd.DataFrame(scaler.fit_transform(enr_df2), columns = enr_df2.columns)
features = enr_norm.drop(
    columns = ["Appliances"]
    )

target = enr_norm["Appliances"]

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(
    features, target, test_size = 0.3, random_state = 42
)

# %% [markdown]
# Question 18

# %%
linear_model = LinearRegression()
linear_model.fit(x_train1, y_train1)
predicted_values1 = linear_model.predict(x_train1)

# %%
mae = mean_absolute_error(y_train1, predicted_values1)
round(mae, 3)
# Out:
# 0.524

# %%
#Question 19
rmse = np.sqrt(mean_squared_error(y_test1, predicted_values1))
round(rmse, 3)
# Out:
# 0.929

# %%
#Question 20
predicted_values2 = linear_model.predict(x_test1)
mae = mean_absolute_error(y_test1, predicted_values2)
round(mae, 3)
# Out:
# 0.523

# %%
#Question 21
rmse = np.sqrt(mean_squared_error(y_test1, predicted_values2))
round(rmse, 3)
# Out:
# 0.913

# %%
#Question 22
ridge_reg = Ridge(alpha = 0.5)
ridge_reg.fit(x_train1, y_train1)
# Out:
# Ridge(alpha=0.5)
